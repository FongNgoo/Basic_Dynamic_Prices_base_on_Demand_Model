# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/Basic_Dynamic_Prices_base_on_Demand_Model
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Basic_Dynamic_Prices_base_on_Demand_Model

# %%
# !git config --global user.email "phongngo4060@gmail.com"
# !git config --global user.name "FongNgoo"

# %%
# !git init
# !git add .
# !git commit -m "First commit from Colab"
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Colab_Notebooks/Basic_Dynamic_Prices_base_on_Demand_Model/.git/
# [master (root-commit) 9ca9fc2] First commit from Colab
#  154 files changed, 34662 insertions(+)
#  create mode 100644 Cache/summary_01-02-24.json
#  create mode 100644 Cache/summary_01-06-24.json
#  create mode 100644 Cache/summary_01-07-24.json
#  create mode 100644 Cache/summary_01-08-24.json
#  create mode 100644 Cache/summary_01-09-24.json
# ...

# %%
# Tạo SSH key
# !ssh-keygen -t rsa -b 4096 -C "phongngo4060@gmail.com" -f /root/.ssh/id_rsa -N ""

# Hiển thị public key
# !cat /root/.ssh/id_rsa.pub
# Out:
# Generating public/private rsa key pair.
# /root/.ssh/id_rsa already exists.
# Overwrite (y/n)? y
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:0/7+dWRylIgolejRhF+jr+cFWSzW5jRZ0DDfT/OXhrw phongngo4060@gmail.com
# The key's randomart image is:
# +---[RSA 4096]----+
# |        =o.  ++. |
# |       +.o.o+ *.o|
# |      ..o.o+.X ++|
# |       ..+. O oo=|
# |        S oo +.oB|
# |         o .. o=.|
# |          o  E  o|
# |         . o.  ..|
# |          ooo..  |
# +----[SHA256]-----+
# ssh-rsa ... phongngo4060@gmail.com

# %%
# !ssh -o StrictHostKeyChecking=no git@github.com
# !git remote set-url origin git@github.com:FongNgoo/Basic_Dynamic_Prices_base_on_Demand_Model.git
# !git push -u origin main
# Out:
# ...
# PTY allocation request failed on channel 0
# Hi FongNgoo! You've successfully authenticated, but GitHub does not provide shell access.
# Connection to github.com closed.
# error: No such remote 'origin'
# error: src refspec main does not match any
# error: failed to push some refs to 'origin'
