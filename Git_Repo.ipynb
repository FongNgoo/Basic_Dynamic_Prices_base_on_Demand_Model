# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/Basic_Dynamic_Prices_base_on_Demand_Model
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Basic_Dynamic_Prices_base_on_Demand_Model

# %%
# !git config --global user.email "phongngo4060@gmail.com"
# !git config --global user.name "FongNgoo"

# %%
# !git init
# !git add .
# !git commit -m "First commit from Colab"
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab_Notebooks/Basic_Dynamic_Prices_base_on_Demand_Model/.git/
# [main 9403153] First commit from Colab
#  9 files changed, 5 insertions(+), 5 deletions(-)
#  rewrite Dynamic_Price_Project_Metadata.ipynb (83%)
#  rewrite Git_Repo.ipynb (98%)
#  create mode 100644 Logs/ai4business_20251116_144457.log
#  rewrite News_Embeding.ipynb (96%)
#  rewrite Output/preprocessed_data.npz (79%)
#  rewrite Output/rpt_demand_best.pth (81%)
#  rewrite Output/scalers.pkl (67%)
#  rewrite PPO.ipynb (95%)
#  rewrite RPT.ipynb (95%)

# %%
# Tạo SSH key
# !ssh-keygen -t rsa -b 4096 -C "phongngo4060@gmail.com" -f /root/.ssh/id_rsa -N ""

# Hiển thị public key
# !cat /root/.ssh/id_rsa.pub
# Out:
# Generating public/private rsa key pair.
# Created directory '/root/.ssh'.
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:Cc5lAUOjN/bYB1l11Uc8uvKjfDx4dvYfxDEV6UMzQ9U phongngo4060@gmail.com
# The key's randomart image is:
# +---[RSA 4096]----+
# |     .=.. ... o*@|
# |     . o +   . BE|
# |    . = =     +o*|
# |     = O o   ..oo|
# |      + S .   .o.|
# |         . . ..  |
# |            =  . |
# |          .. O o.|
# |           o= = =|
# +----[SHA256]-----+
# ssh-rsa ... phongngo4060@gmail.com

# %%
# !ssh -T git@github.com
# Out:
# Host key verification failed.

# %%
# !git add .
# !git commit -m "First commit from Colab"
# Out:
# [main def3882] First commit from Colab
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Git_Repo.ipynb (84%)

# %%
# !git remote add origin git@github.com:FongNgoo/Basic_Dynamic_Prices_base_on_Demand_Model.git
# Out:
# error: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	git@github.com:FongNgoo/Basic_Dynamic_Prices_base_on_Demand_Model.git (fetch)
# origin	git@github.com:FongNgoo/Basic_Dynamic_Prices_base_on_Demand_Model.git (push)

# %%
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
